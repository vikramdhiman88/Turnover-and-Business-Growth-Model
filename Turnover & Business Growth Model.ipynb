# %% [markdown]
# # Turnover & Business Growth

# %% [raw]
# Equity : Business Growth in CM Segment

# %% [markdown]
# # Indexes Used :-

# %% [raw]
# •	YEAR
# •	NO OF CO.S LISTED*
# •	NO. OF CO.S PERMITTED*
# •	NO. OF CO.S AVAILABLE FOR TRADING*
# •	NO. OF TRADING DAYS
# •	NO. OF SECURITIES TRADED #
# •	NO. OF TRADES(in Lakhs)
# •	VOLUME(shares) (in Lakhs)
# •	VALUE(₹ Lakhs)
# •	AVERAGE DAILY TURNOVER(₹ Lakhs)
# •	AVERAGE TRADE SIZE
# •	VOLUME(shares) Demat (in Lakhs)
# •	VALUE(₹ Lakhs) Demat
# •	MARKET CAPITALISATION(₹ Lakhs)

# %% [markdown]
# # Key Terms :-

# %% [raw]
# Listed :- Listed describes companies that are included and traded on a given stock exchange.
# Companies must meet certain requirements and follow the rules of any exchange on which it is listed.
#
# Trading day :- Trading day is the time span that a stock exchange is open, as opposed to electronic or extended trading hours (ETH)
#
# Daily Turnover :- Daily Turnover means, for any Share, the daily sum of the products of (i) each trade price of such Share on the Exchange and any Related Exchanges for such Share and (ii) the traded volume of such trade for such Share on the relevant Exchange or Related Exchange
#
# Trade Size :- Refers to the magnitude of an offering, an order, or a trade. Large as in the size of an offering, the size of an order, or the size of a trade. Size is relative from market to market and security to security.
#
# Market Capitalisation :- The value of a company that is traded on the stock market, calculated by multiplying the total number of shares by the present share price.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("TradeGrowth.csv", index_col = 0)
df
# Out:
#           YEAR  NO_OF_COS_LISTED  NO_OF_COS_PERMITTED  \
# SNO
# 1    2020-2021              1969                 24.0
# 2    2019-2020              1949                 18.0
# 3    2018-2019              1931                  4.0
# 4    2017-2018              1931                  4.0
# 5    2016-2017              1817                  4.0
# 6    2015-2016              1808                  4.0
# 7    2014-2015              1733                  4.0
# 8    2013-2014              1688                 75.0
# 9    2012-2013              1666                 76.0
# 10   2011-2012              1646                 73.0
# 11   2010-2011              1574                 61.0
# 12   2009-2010              1470                 37.0
# 13   2008-2009              1432                  NaN
# 14   2007-2008              1381                  NaN
# 15   2006-2007              1228                  NaN
# 16   2005-2006              1069                  NaN
# ...

# %%
df.describe()
# Out:
#        NO_OF_COS_LISTED  NO_OF_COS_PERMITTED  NO_OF_COS_AVAILABLE_FOR_TRADING  \
# count         27.000000            23.000000                        27.000000
# mean        1246.444444           225.391304                      1332.851852
# std          548.881473           305.057035                       366.322441
# min          135.000000             1.000000                       678.000000
# 25%          789.000000            11.000000                      1056.500000
# 50%         1381.000000            73.000000                      1357.000000
# 75%         1710.500000           399.500000                      1584.000000
# max         1969.000000           934.000000                      1910.000000
#
#        NO_OF_TRADING_DAYS  NO_OF_SECURITIES_TRADED   NO_OF_TRADES_inLakhs  \
# count           26.000000                 20.000000             26.000000
# mean           269.384615               1708.450000          11283.000000
# ...

# %%
df.count()
# Out:
# YEAR                               27
# NO_OF_COS_LISTED                   27
# NO_OF_COS_PERMITTED                23
# NO_OF_COS_AVAILABLE_FOR_TRADING    27
# NO_OF_TRADING_DAYS                 26
# NO_OF_SECURITIES_TRADED            20
# NO_OF_TRADES_inLakhs               26
# VOLUME_Shares_inLakhs              26
# VALUE_inLakhs                      26
# AVERAGE_DAILY_TURNOVER_inLakhs     26
# AVERAGE_TRADE_SIZE                 26
# VOLUME_shares_Demat_inLakhs        22
# VALUE_inLakhs_Demat                22
# MARKET_CAPITALISATION_inLakhs      26
# dtype: int64

# %%
df.nunique()
# Out:
# YEAR                               27
# NO_OF_COS_LISTED                   26
# NO_OF_COS_PERMITTED                18
# NO_OF_COS_AVAILABLE_FOR_TRADING    26
# NO_OF_TRADING_DAYS                 13
# NO_OF_SECURITIES_TRADED            20
# NO_OF_TRADES_inLakhs               26
# VOLUME_Shares_inLakhs              26
# VALUE_inLakhs                      26
# AVERAGE_DAILY_TURNOVER_inLakhs     26
# AVERAGE_TRADE_SIZE                 26
# VOLUME_shares_Demat_inLakhs        22
# VALUE_inLakhs_Demat                22
# MARKET_CAPITALISATION_inLakhs      26
# dtype: int64

# %%
plt.hist(df.NO_OF_COS_LISTED)
# Out:
# (array([1., 1., 3., 4., 2., 2., 1., 3., 4., 6.]),
#  array([ 135. ,  318.4,  501.8,  685.2,  868.6, 1052. , 1235.4, 1418.8,
#         1602.2, 1785.6, 1969. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.NO_OF_TRADES_inLakhs)
# Out:
# (array([12.,  1.,  3.,  6.,  0.,  1.,  2.,  0.,  0.,  1.]),
#  array([3.00000e+00, 4.63550e+03, 9.26800e+03, 1.39005e+04, 1.85330e+04,
#         2.31655e+04, 2.77980e+04, 3.24305e+04, 3.70630e+04, 4.16955e+04,
#         4.63280e+04]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.boxplot(y = df.YEAR,x = df.NO_OF_COS_LISTED)
# Out:
# <AxesSubplot:xlabel='NO_OF_COS_LISTED', ylabel='YEAR'>

# %%
sns.boxplot(x = df.NO_OF_TRADES_inLakhs, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='NO_OF_TRADES_inLakhs', ylabel='YEAR'>

# %%
sns.boxplot(x = df.MARKET_CAPITALISATION_inLakhs, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='MARKET_CAPITALISATION_inLakhs', ylabel='YEAR'>

# %%
sns.boxplot(x = df.NO_OF_TRADING_DAYS, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='NO_OF_TRADING_DAYS', ylabel='YEAR'>

# %%
sns.boxplot(x = df.AVERAGE_DAILY_TURNOVER_inLakhs, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='AVERAGE_DAILY_TURNOVER_inLakhs', ylabel='YEAR'>

# %%
sns.boxplot(x = df.VOLUME_shares_Demat_inLakhs, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='VOLUME_shares_Demat_inLakhs', ylabel='YEAR'>

# %%
sns.boxplot(x = df.VALUE_inLakhs_Demat, y = df.YEAR)
# Out:
# <AxesSubplot:xlabel='VALUE_inLakhs_Demat', ylabel='YEAR'>

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df,x="AVERAGE_TRADE_SIZE")
# Out:
# <AxesSubplot:xlabel='AVERAGE_TRADE_SIZE'>

# %%
#How to create Confusion Matrix

# %%
#How to predict future of Stock Market
